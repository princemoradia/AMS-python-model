# %%
import cv2 as cv

# %%
# cap = cv.VideoCapture(0)

# while True:
    
#     ret,frame = cap.read()
    
#     cv.imshow("frame",frame)
    
#     if cv.waitKey(2) & 0xFF == ord('x'):
#         break
# cap.release()
# cv.destroyAllWindows()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from utils.Inceptionresnet import *

# %%
import tensorflow as tf
import keras
from keras import models
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPool2D,Input,Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
K.set_image_data_format('channels_last')
from keras.models import Model
import h5py
import numpy as np

# %%
facenet_encoder = InceptionResNetV2()
facenet_encoder.load_weights("utils/facenet_keras_weights.h5")
FRmodel = facenet_encoder

# %%
print(FRmodel.inputs)
print(FRmodel.outputs)
# Out:
# [<KerasTensor: shape=(None, 160, 160, 3) dtype=float32 (created by layer 'input_1')>]
# [<KerasTensor: shape=(None, 128) dtype=float32 (created by layer 'Bottleneck_BatchNorm')>]

# %%
FRmodel.summary()
# Out:
# Model: "inception_resnet_v1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv2d_1a_3x3 (Conv2D)         (None, 79, 79, 32)   864         ['input_1[0][0]']
#
#  Conv2d_1a_3x3_BatchNorm (Batch  (None, 79, 79, 32)  96          ['Conv2d_1a_3x3[0][0]']
#  Normalization)
#
#  Conv2d_1a_3x3_Activation (Acti  (None, 79, 79, 32)  0           ['Conv2d_1a_3x3_BatchNorm[0][0]']
#  vation)
#
#  Conv2d_2a_3x3 (Conv2D)         (None, 77, 77, 32)   9216        ['Conv2d_1a_3x3_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_2a_3x3_BatchNorm (Batch  (None, 77, 77, 32)  96          ['Conv2d_2a_3x3[0][0]']
#  Normalization)
#
#  Conv2d_2a_3x3_Activation (Acti  (None, 77, 77, 32)  0           ['Conv2d_2a_3x3_BatchNorm[0][0]']
#  vation)
#
#  Conv2d_2b_3x3 (Conv2D)         (None, 77, 77, 64)   18432       ['Conv2d_2a_3x3_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_2b_3x3_BatchNorm (Batch  (None, 77, 77, 64)  192         ['Conv2d_2b_3x3[0][0]']
#  Normalization)
#
#  Conv2d_2b_3x3_Activation (Acti  (None, 77, 77, 64)  0           ['Conv2d_2b_3x3_BatchNorm[0][0]']
#  vation)
#
#  MaxPool_3a_3x3 (MaxPooling2D)  (None, 38, 38, 64)   0           ['Conv2d_2b_3x3_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_3b_1x1 (Conv2D)         (None, 38, 38, 80)   5120        ['MaxPool_3a_3x3[0][0]']
#
#  Conv2d_3b_1x1_BatchNorm (Batch  (None, 38, 38, 80)  240         ['Conv2d_3b_1x1[0][0]']
#  Normalization)
#
#  Conv2d_3b_1x1_Activation (Acti  (None, 38, 38, 80)  0           ['Conv2d_3b_1x1_BatchNorm[0][0]']
#  vation)
#
#  Conv2d_4a_3x3 (Conv2D)         (None, 36, 36, 192)  138240      ['Conv2d_3b_1x1_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_4a_3x3_BatchNorm (Batch  (None, 36, 36, 192)  576        ['Conv2d_4a_3x3[0][0]']
#  Normalization)
#
#  Conv2d_4a_3x3_Activation (Acti  (None, 36, 36, 192)  0          ['Conv2d_4a_3x3_BatchNorm[0][0]']
#  vation)
#
#  Conv2d_4b_3x3 (Conv2D)         (None, 17, 17, 256)  442368      ['Conv2d_4a_3x3_Activation[0][0]'
#                                                                  ]
#
#  Conv2d_4b_3x3_BatchNorm (Batch  (None, 17, 17, 256)  768        ['Conv2d_4b_3x3[0][0]']
#  Normalization)
#
#  Conv2d_4b_3x3_Activation (Acti  (None, 17, 17, 256)  0          ['Conv2d_4b_3x3_BatchNorm[0][0]']
#  vation)
#
#  Block35_1_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Conv2d_4b_3x3_Activation[0][0]'
#  x1 (Conv2D)                                                     ]
#
#  Block35_1_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_1_Branch_2_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_1_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_1_Branch_2_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_1_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Conv2d_4b_3x3_Activation[0][0]'
#  x1 (Conv2D)                                                     ]
#
#  Block35_1_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_1_Branch_2_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_1_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_1_Branch_1_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_1_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_1_Branch_2_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_1_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_1_Branch_1_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_1_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_1_Branch_2_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_1_Branch_0_Conv2d_1x1   (None, 17, 17, 32)  8192        ['Conv2d_4b_3x3_Activation[0][0]'
#  (Conv2D)                                                        ]
#
#  Block35_1_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_1_Branch_1_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_1_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  9216        ['Block35_1_Branch_2_Conv2d_0b_3x
#  x3 (Conv2D)                                                     3_Activation[0][0]']
#
#  Block35_1_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  96          ['Block35_1_Branch_0_Conv2d_1x1[0
#  BatchNorm (BatchNormalization)                                  ][0]']
#
#  Block35_1_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_1_Branch_1_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_1_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  96          ['Block35_1_Branch_2_Conv2d_0c_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_1_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  0           ['Block35_1_Branch_0_Conv2d_1x1_B
#  Activation (Activation)                                         atchNorm[0][0]']
#
#  Block35_1_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_1_Branch_1_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_1_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  0           ['Block35_1_Branch_2_Conv2d_0c_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_1_Concatenate (Concate  (None, 17, 17, 96)  0           ['Block35_1_Branch_0_Conv2d_1x1_A
#  nate)                                                           ctivation[0][0]',
#                                                                   'Block35_1_Branch_1_Conv2d_0b_3x
#                                                                  3_Activation[0][0]',
#                                                                   'Block35_1_Branch_2_Conv2d_0c_3x
#                                                                  3_Activation[0][0]']
#
#  Block35_1_Conv2d_1x1 (Conv2D)  (None, 17, 17, 256)  24832       ['Block35_1_Concatenate[0][0]']
#
#  lambda (Lambda)                (None, 17, 17, 256)  0           ['Block35_1_Conv2d_1x1[0][0]']
#
#  add (Add)                      (None, 17, 17, 256)  0           ['Conv2d_4b_3x3_Activation[0][0]'
#                                                                  , 'lambda[0][0]']
#
#  Block35_1_Activation (Activati  (None, 17, 17, 256)  0          ['add[0][0]']
#  on)
#
#  Block35_2_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_1_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_2_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_2_Branch_2_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_2_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_2_Branch_2_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_2_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_1_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_2_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_2_Branch_2_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_2_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_2_Branch_1_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_2_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_2_Branch_2_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_2_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_2_Branch_1_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_2_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_2_Branch_2_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_2_Branch_0_Conv2d_1x1   (None, 17, 17, 32)  8192        ['Block35_1_Activation[0][0]']
#  (Conv2D)
#
#  Block35_2_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_2_Branch_1_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_2_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  9216        ['Block35_2_Branch_2_Conv2d_0b_3x
#  x3 (Conv2D)                                                     3_Activation[0][0]']
#
#  Block35_2_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  96          ['Block35_2_Branch_0_Conv2d_1x1[0
#  BatchNorm (BatchNormalization)                                  ][0]']
#
#  Block35_2_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_2_Branch_1_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_2_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  96          ['Block35_2_Branch_2_Conv2d_0c_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_2_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  0           ['Block35_2_Branch_0_Conv2d_1x1_B
#  Activation (Activation)                                         atchNorm[0][0]']
#
#  Block35_2_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_2_Branch_1_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_2_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  0           ['Block35_2_Branch_2_Conv2d_0c_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_2_Concatenate (Concate  (None, 17, 17, 96)  0           ['Block35_2_Branch_0_Conv2d_1x1_A
#  nate)                                                           ctivation[0][0]',
#                                                                   'Block35_2_Branch_1_Conv2d_0b_3x
#                                                                  3_Activation[0][0]',
#                                                                   'Block35_2_Branch_2_Conv2d_0c_3x
#                                                                  3_Activation[0][0]']
#
#  Block35_2_Conv2d_1x1 (Conv2D)  (None, 17, 17, 256)  24832       ['Block35_2_Concatenate[0][0]']
#
#  lambda_1 (Lambda)              (None, 17, 17, 256)  0           ['Block35_2_Conv2d_1x1[0][0]']
#
#  add_1 (Add)                    (None, 17, 17, 256)  0           ['Block35_1_Activation[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  Block35_2_Activation (Activati  (None, 17, 17, 256)  0          ['add_1[0][0]']
#  on)
#
#  Block35_3_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_2_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_3_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_3_Branch_2_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_3_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_3_Branch_2_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_3_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_2_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_3_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_3_Branch_2_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_3_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_3_Branch_1_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_3_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_3_Branch_2_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_3_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_3_Branch_1_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_3_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_3_Branch_2_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_3_Branch_0_Conv2d_1x1   (None, 17, 17, 32)  8192        ['Block35_2_Activation[0][0]']
#  (Conv2D)
#
#  Block35_3_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_3_Branch_1_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#  Block35_3_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  9216        ['Block35_3_Branch_2_Conv2d_0b_3x
#  x3 (Conv2D)                                                     3_Activation[0][0]']
#
#  Block35_3_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  96          ['Block35_3_Branch_0_Conv2d_1x1[0
#  BatchNorm (BatchNormalization)                                  ][0]']
#
#  Block35_3_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_3_Branch_1_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_3_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  96          ['Block35_3_Branch_2_Conv2d_0c_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_3_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  0           ['Block35_3_Branch_0_Conv2d_1x1_B
#  Activation (Activation)                                         atchNorm[0][0]']
#
#  Block35_3_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_3_Branch_1_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_3_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  0           ['Block35_3_Branch_2_Conv2d_0c_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_3_Concatenate (Concate  (None, 17, 17, 96)  0           ['Block35_3_Branch_0_Conv2d_1x1_A
#  nate)                                                           ctivation[0][0]',
#                                                                   'Block35_3_Branch_1_Conv2d_0b_3x
#                                                                  3_Activation[0][0]',
#                                                                   'Block35_3_Branch_2_Conv2d_0c_3x
#                                                                  3_Activation[0][0]']
#
#  Block35_3_Conv2d_1x1 (Conv2D)  (None, 17, 17, 256)  24832       ['Block35_3_Concatenate[0][0]']
#
#  lambda_2 (Lambda)              (None, 17, 17, 256)  0           ['Block35_3_Conv2d_1x1[0][0]']
#
#  add_2 (Add)                    (None, 17, 17, 256)  0           ['Block35_2_Activation[0][0]',
#                                                                   'lambda_2[0][0]']
#
#  Block35_3_Activation (Activati  (None, 17, 17, 256)  0          ['add_2[0][0]']
#  on)
#
#  Block35_4_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_3_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_4_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_4_Branch_2_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_4_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_4_Branch_2_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_4_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_3_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_4_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_4_Branch_2_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_4_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_4_Branch_1_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_4_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_4_Branch_2_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_4_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_4_Branch_1_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_4_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_4_Branch_2_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_4_Branch_0_Conv2d_1x1   (None, 17, 17, 32)  8192        ['Block35_3_Activation[0][0]']
#  (Conv2D)
#
#  Block35_4_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_4_Branch_1_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_4_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  9216        ['Block35_4_Branch_2_Conv2d_0b_3x
#  x3 (Conv2D)                                                     3_Activation[0][0]']
#
#  Block35_4_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  96          ['Block35_4_Branch_0_Conv2d_1x1[0
#  BatchNorm (BatchNormalization)                                  ][0]']
#
#  Block35_4_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_4_Branch_1_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_4_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  96          ['Block35_4_Branch_2_Conv2d_0c_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_4_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  0           ['Block35_4_Branch_0_Conv2d_1x1_B
#  Activation (Activation)                                         atchNorm[0][0]']
#
#  Block35_4_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_4_Branch_1_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_4_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  0           ['Block35_4_Branch_2_Conv2d_0c_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_4_Concatenate (Concate  (None, 17, 17, 96)  0           ['Block35_4_Branch_0_Conv2d_1x1_A
#  nate)                                                           ctivation[0][0]',
#                                                                   'Block35_4_Branch_1_Conv2d_0b_3x
#                                                                  3_Activation[0][0]',
#                                                                   'Block35_4_Branch_2_Conv2d_0c_3x
#                                                                  3_Activation[0][0]']
#
#  Block35_4_Conv2d_1x1 (Conv2D)  (None, 17, 17, 256)  24832       ['Block35_4_Concatenate[0][0]']
#
#  lambda_3 (Lambda)              (None, 17, 17, 256)  0           ['Block35_4_Conv2d_1x1[0][0]']
#
#  add_3 (Add)                    (None, 17, 17, 256)  0           ['Block35_3_Activation[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  Block35_4_Activation (Activati  (None, 17, 17, 256)  0          ['add_3[0][0]']
#  on)
#
#  Block35_5_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_4_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_5_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_5_Branch_2_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_5_Branch_2_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_5_Branch_2_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_5_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  8192        ['Block35_4_Activation[0][0]']
#  x1 (Conv2D)
#
#  Block35_5_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_5_Branch_2_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_5_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  96          ['Block35_5_Branch_1_Conv2d_0a_1x
#  x1_BatchNorm (BatchNormalizati                                  1[0][0]']
#  on)
#
#  Block35_5_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_5_Branch_2_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_5_Branch_1_Conv2d_0a_1  (None, 17, 17, 32)  0           ['Block35_5_Branch_1_Conv2d_0a_1x
#  x1_Activation (Activation)                                      1_BatchNorm[0][0]']
#
#  Block35_5_Branch_2_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_5_Branch_2_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_5_Branch_0_Conv2d_1x1   (None, 17, 17, 32)  8192        ['Block35_4_Activation[0][0]']
#  (Conv2D)
#
#  Block35_5_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  9216        ['Block35_5_Branch_1_Conv2d_0a_1x
#  x3 (Conv2D)                                                     1_Activation[0][0]']
#
#  Block35_5_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  9216        ['Block35_5_Branch_2_Conv2d_0b_3x
#  x3 (Conv2D)                                                     3_Activation[0][0]']
#
#  Block35_5_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  96          ['Block35_5_Branch_0_Conv2d_1x1[0
#  BatchNorm (BatchNormalization)                                  ][0]']
#
#  Block35_5_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  96          ['Block35_5_Branch_1_Conv2d_0b_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#
#  Block35_5_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  96          ['Block35_5_Branch_2_Conv2d_0c_3x
#  x3_BatchNorm (BatchNormalizati                                  3[0][0]']
#  on)
#  Block35_5_Branch_0_Conv2d_1x1_  (None, 17, 17, 32)  0           ['Block35_5_Branch_0_Conv2d_1x1_B
#  Activation (Activation)                                         atchNorm[0][0]']
#
#  Block35_5_Branch_1_Conv2d_0b_3  (None, 17, 17, 32)  0           ['Block35_5_Branch_1_Conv2d_0b_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_5_Branch_2_Conv2d_0c_3  (None, 17, 17, 32)  0           ['Block35_5_Branch_2_Conv2d_0c_3x
#  x3_Activation (Activation)                                      3_BatchNorm[0][0]']
#
#  Block35_5_Concatenate (Concate  (None, 17, 17, 96)  0           ['Block35_5_Branch_0_Conv2d_1x1_A
#  nate)                                                           ctivation[0][0]',
#                                                                   'Block35_5_Branch_1_Conv2d_0b_3x
#                                                                  3_Activation[0][0]',
#                                                                   'Block35_5_Branch_2_Conv2d_0c_3x
#                                                                  3_Activation[0][0]']
#
#  Block35_5_Conv2d_1x1 (Conv2D)  (None, 17, 17, 256)  24832       ['Block35_5_Concatenate[0][0]']
#
#  lambda_4 (Lambda)              (None, 17, 17, 256)  0           ['Block35_5_Conv2d_1x1[0][0]']
#
#  add_4 (Add)                    (None, 17, 17, 256)  0           ['Block35_4_Activation[0][0]',
#                                                                   'lambda_4[0][0]']
#
#  Block35_5_Activation (Activati  (None, 17, 17, 256)  0          ['add_4[0][0]']
#  on)
#
#  Mixed_6a_Branch_1_Conv2d_0a_1x  (None, 17, 17, 192)  49152      ['Block35_5_Activation[0][0]']
#  1 (Conv2D)
#
#  Mixed_6a_Branch_1_Conv2d_0a_1x  (None, 17, 17, 192)  576        ['Mixed_6a_Branch_1_Conv2d_0a_1x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Mixed_6a_Branch_1_Conv2d_0a_1x  (None, 17, 17, 192)  0          ['Mixed_6a_Branch_1_Conv2d_0a_1x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Mixed_6a_Branch_1_Conv2d_0b_3x  (None, 17, 17, 192)  331776     ['Mixed_6a_Branch_1_Conv2d_0a_1x1
#  3 (Conv2D)                                                      _Activation[0][0]']
#
#  Mixed_6a_Branch_1_Conv2d_0b_3x  (None, 17, 17, 192)  576        ['Mixed_6a_Branch_1_Conv2d_0b_3x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Mixed_6a_Branch_1_Conv2d_0b_3x  (None, 17, 17, 192)  0          ['Mixed_6a_Branch_1_Conv2d_0b_3x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Mixed_6a_Branch_0_Conv2d_1a_3x  (None, 8, 8, 384)   884736      ['Block35_5_Activation[0][0]']
#  3 (Conv2D)
#
#  Mixed_6a_Branch_1_Conv2d_1a_3x  (None, 8, 8, 256)   442368      ['Mixed_6a_Branch_1_Conv2d_0b_3x3
#  3 (Conv2D)                                                      _Activation[0][0]']
#
#  Mixed_6a_Branch_0_Conv2d_1a_3x  (None, 8, 8, 384)   1152        ['Mixed_6a_Branch_0_Conv2d_1a_3x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Mixed_6a_Branch_1_Conv2d_1a_3x  (None, 8, 8, 256)   768         ['Mixed_6a_Branch_1_Conv2d_1a_3x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Mixed_6a_Branch_0_Conv2d_1a_3x  (None, 8, 8, 384)   0           ['Mixed_6a_Branch_0_Conv2d_1a_3x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Mixed_6a_Branch_1_Conv2d_1a_3x  (None, 8, 8, 256)   0           ['Mixed_6a_Branch_1_Conv2d_1a_3x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Mixed_6a_Branch_2_MaxPool_1a_3  (None, 8, 8, 256)   0           ['Block35_5_Activation[0][0]']
#  x3 (MaxPooling2D)
#
#  Mixed_6a (Concatenate)         (None, 8, 8, 896)    0           ['Mixed_6a_Branch_0_Conv2d_1a_3x3
#                                                                  _Activation[0][0]',
#                                                                   'Mixed_6a_Branch_1_Conv2d_1a_3x3
#                                                                  _Activation[0][0]',
# ...
#  3 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_4_Branch_4_Conv2d_0b_1x  (None, 3, 3, 192)   576         ['Block8_4_Branch_4_Conv2d_0b_1x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_4_Branch_4_Conv2d_0b_1x  (None, 3, 3, 192)   0           ['Block8_4_Branch_4_Conv2d_0b_1x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_4_Branch_0_Conv2d_1x1 (  (None, 3, 3, 192)   344064      ['Block8_3_Activation[0][0]']
#  Conv2D)
#
#  Block8_4_Branch_4_Conv2d_0c_3x  (None, 3, 3, 192)   110592      ['Block8_4_Branch_4_Conv2d_0b_1x3
#  1 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_4_Branch_0_Conv2d_1x1_B  (None, 3, 3, 192)   576         ['Block8_4_Branch_0_Conv2d_1x1[0]
#  atchNorm (BatchNormalization)                                   [0]']
#
#  Block8_4_Branch_4_Conv2d_0c_3x  (None, 3, 3, 192)   576         ['Block8_4_Branch_4_Conv2d_0c_3x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_4_Branch_0_Conv2d_1x1_A  (None, 3, 3, 192)   0           ['Block8_4_Branch_0_Conv2d_1x1_Ba
#  ctivation (Activation)                                          tchNorm[0][0]']
#
#  Block8_4_Branch_4_Conv2d_0c_3x  (None, 3, 3, 192)   0           ['Block8_4_Branch_4_Conv2d_0c_3x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_4_Concatenate (Concaten  (None, 3, 3, 384)   0           ['Block8_4_Branch_0_Conv2d_1x1_Ac
#  ate)                                                            tivation[0][0]',
#                                                                   'Block8_4_Branch_4_Conv2d_0c_3x1
#                                                                  _Activation[0][0]']
#
#  Block8_4_Conv2d_1x1 (Conv2D)   (None, 3, 3, 1792)   689920      ['Block8_4_Concatenate[0][0]']
#
#  lambda_18 (Lambda)             (None, 3, 3, 1792)   0           ['Block8_4_Conv2d_1x1[0][0]']
#
#  add_18 (Add)                   (None, 3, 3, 1792)   0           ['Block8_3_Activation[0][0]',
#                                                                   'lambda_18[0][0]']
#
#  Block8_4_Activation (Activatio  (None, 3, 3, 1792)  0           ['add_18[0][0]']
#  n)
#
#  Block8_5_Branch_5_Conv2d_0a_1x  (None, 3, 3, 192)   344064      ['Block8_4_Activation[0][0]']
#  1 (Conv2D)
#
#  Block8_5_Branch_5_Conv2d_0a_1x  (None, 3, 3, 192)   576         ['Block8_5_Branch_5_Conv2d_0a_1x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_5_Branch_5_Conv2d_0a_1x  (None, 3, 3, 192)   0           ['Block8_5_Branch_5_Conv2d_0a_1x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_5_Branch_5_Conv2d_0b_1x  (None, 3, 3, 192)   110592      ['Block8_5_Branch_5_Conv2d_0a_1x1
#  3 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_5_Branch_5_Conv2d_0b_1x  (None, 3, 3, 192)   576         ['Block8_5_Branch_5_Conv2d_0b_1x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_5_Branch_5_Conv2d_0b_1x  (None, 3, 3, 192)   0           ['Block8_5_Branch_5_Conv2d_0b_1x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_5_Branch_0_Conv2d_1x1 (  (None, 3, 3, 192)   344064      ['Block8_4_Activation[0][0]']
#  Conv2D)
#
#  Block8_5_Branch_5_Conv2d_0c_3x  (None, 3, 3, 192)   110592      ['Block8_5_Branch_5_Conv2d_0b_1x3
#  1 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_5_Branch_0_Conv2d_1x1_B  (None, 3, 3, 192)   576         ['Block8_5_Branch_0_Conv2d_1x1[0]
#  atchNorm (BatchNormalization)                                   [0]']
#
#  Block8_5_Branch_5_Conv2d_0c_3x  (None, 3, 3, 192)   576         ['Block8_5_Branch_5_Conv2d_0c_3x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_5_Branch_0_Conv2d_1x1_A  (None, 3, 3, 192)   0           ['Block8_5_Branch_0_Conv2d_1x1_Ba
#  ctivation (Activation)                                          tchNorm[0][0]']
#
#  Block8_5_Branch_5_Conv2d_0c_3x  (None, 3, 3, 192)   0           ['Block8_5_Branch_5_Conv2d_0c_3x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_5_Concatenate (Concaten  (None, 3, 3, 384)   0           ['Block8_5_Branch_0_Conv2d_1x1_Ac
#  ate)                                                            tivation[0][0]',
#                                                                   'Block8_5_Branch_5_Conv2d_0c_3x1
#                                                                  _Activation[0][0]']
#
#  Block8_5_Conv2d_1x1 (Conv2D)   (None, 3, 3, 1792)   689920      ['Block8_5_Concatenate[0][0]']
#
#  lambda_19 (Lambda)             (None, 3, 3, 1792)   0           ['Block8_5_Conv2d_1x1[0][0]']
#
#  add_19 (Add)                   (None, 3, 3, 1792)   0           ['Block8_4_Activation[0][0]',
#                                                                   'lambda_19[0][0]']
#
#  Block8_5_Activation (Activatio  (None, 3, 3, 1792)  0           ['add_19[0][0]']
#  n)
#
#  Block8_6_Branch_1_Conv2d_0a_1x  (None, 3, 3, 192)   344064      ['Block8_5_Activation[0][0]']
#  1 (Conv2D)
#
#  Block8_6_Branch_1_Conv2d_0a_1x  (None, 3, 3, 192)   576         ['Block8_6_Branch_1_Conv2d_0a_1x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_6_Branch_1_Conv2d_0a_1x  (None, 3, 3, 192)   0           ['Block8_6_Branch_1_Conv2d_0a_1x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_6_Branch_1_Conv2d_0b_1x  (None, 3, 3, 192)   110592      ['Block8_6_Branch_1_Conv2d_0a_1x1
#  3 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_6_Branch_1_Conv2d_0b_1x  (None, 3, 3, 192)   576         ['Block8_6_Branch_1_Conv2d_0b_1x3
#  3_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_6_Branch_1_Conv2d_0b_1x  (None, 3, 3, 192)   0           ['Block8_6_Branch_1_Conv2d_0b_1x3
#  3_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_6_Branch_0_Conv2d_1x1 (  (None, 3, 3, 192)   344064      ['Block8_5_Activation[0][0]']
#  Conv2D)
#
#  Block8_6_Branch_1_Conv2d_0c_3x  (None, 3, 3, 192)   110592      ['Block8_6_Branch_1_Conv2d_0b_1x3
#  1 (Conv2D)                                                      _Activation[0][0]']
#
#  Block8_6_Branch_0_Conv2d_1x1_B  (None, 3, 3, 192)   576         ['Block8_6_Branch_0_Conv2d_1x1[0]
#  atchNorm (BatchNormalization)                                   [0]']
#
#  Block8_6_Branch_1_Conv2d_0c_3x  (None, 3, 3, 192)   576         ['Block8_6_Branch_1_Conv2d_0c_3x1
#  1_BatchNorm (BatchNormalizatio                                  [0][0]']
#  n)
#
#  Block8_6_Branch_0_Conv2d_1x1_A  (None, 3, 3, 192)   0           ['Block8_6_Branch_0_Conv2d_1x1_Ba
#  ctivation (Activation)                                          tchNorm[0][0]']
#
#  Block8_6_Branch_1_Conv2d_0c_3x  (None, 3, 3, 192)   0           ['Block8_6_Branch_1_Conv2d_0c_3x1
#  1_Activation (Activation)                                       _BatchNorm[0][0]']
#
#  Block8_6_Concatenate (Concaten  (None, 3, 3, 384)   0           ['Block8_6_Branch_0_Conv2d_1x1_Ac
#  ate)                                                            tivation[0][0]',
#                                                                   'Block8_6_Branch_1_Conv2d_0c_3x1
#                                                                  _Activation[0][0]']
#
#  Block8_6_Conv2d_1x1 (Conv2D)   (None, 3, 3, 1792)   689920      ['Block8_6_Concatenate[0][0]']
#
#  lambda_20 (Lambda)             (None, 3, 3, 1792)   0           ['Block8_6_Conv2d_1x1[0][0]']
#
#  add_20 (Add)                   (None, 3, 3, 1792)   0           ['Block8_5_Activation[0][0]',
#                                                                   'lambda_20[0][0]']
#
#  AvgPool (GlobalAveragePooling2  (None, 1792)        0           ['add_20[0][0]']
#  D)
#
#  Dropout (Dropout)              (None, 1792)         0           ['AvgPool[0][0]']
#
#  Bottleneck (Dense)             (None, 128)          229376      ['Dropout[0][0]']
#
#  Bottleneck_BatchNorm (BatchNor  (None, 128)         384         ['Bottleneck[0][0]']
#  malization)
#
# ==================================================================================================
# Total params: 22,808,144
# Trainable params: 22,779,312
# Non-trainable params: 28,832
# __________________________________________________________________________________________________

# %%
from skimage.transform import resize


def img_to_encoding(image, model):
    if image is None:
        return 0
    else:
        img = cv.resize(image,(160,160))
        img = np.around(np.asarray(img)/255.0, decimals=12)
        x_train = np.expand_dims(img, axis=0)
        embedding = model.predict_on_batch(x_train)
        return embedding / np.linalg.norm(embedding, ord=2)

# %%
filepath = "extract_face/"
database = {}

def load_image(filepath):
    
    for folder in os.listdir(filepath):
        encodings = []
        for subfolder in os.listdir(filepath+folder):
            image_BGR = cv.imread(filepath + folder + "/" + subfolder)
            
            temp = img_to_encoding(image_BGR,FRmodel)
            encodings.append(temp)
        database[folder] = encodings
    return database

# %%
 database = load_image(filepath)

# %%
database["Prince"][10].shape
# Out:
# (1, 128)

# %%
print(database.items())
# Out:
# dict_items([('Abhi', [array([[ 0.02068297, -0.01604011, -0.08955532,  0.05583676,  0.02162544,
#         -0.0628331 ,  0.02130852, -0.13848968, -0.07832345,  0.13074099,
#         -0.12317941, -0.15530987, -0.11236671, -0.05847793,  0.07243551,
#          0.01841416,  0.09190463, -0.06605355,  0.01156814, -0.16260362,
#          0.13500682, -0.0922985 ,  0.06637803,  0.06649935,  0.14304133,
#         -0.00581338, -0.00210483,  0.06589484,  0.04895082,  0.20700641,
#          0.08103833, -0.01069203, -0.02981001,  0.04828461,  0.1424793 ,
#         -0.02060016, -0.05232676, -0.00716505,  0.1885734 ,  0.01961722,
#         -0.15096465,  0.09344038,  0.0742761 ,  0.01870793,  0.15188515,
#          0.14620714, -0.10442546,  0.02208454, -0.12151846,  0.05096523,
#         -0.1533642 , -0.02903488, -0.0330454 ,  0.09123479, -0.04741023,
#          0.09471291,  0.0912241 , -0.05111816, -0.02987656, -0.02421962,
#         -0.08847174, -0.0320111 ,  0.10343746, -0.13857713, -0.15639973,
#         -0.02654989, -0.11775631, -0.00770302, -0.06835135, -0.05169112,
#          0.13090482,  0.03830661, -0.06665146, -0.09725221, -0.02670032,
#         -0.01476189,  0.01729081, -0.01985578,  0.02144642,  0.03147482,
#          0.12436042,  0.03182223,  0.00057625, -0.02919661,  0.02150014,
#          0.00565283, -0.04919843, -0.03300241, -0.08011401, -0.04201139,
#          0.09450141,  0.10199548, -0.02677247,  0.16978182, -0.05082077,
#          0.04504883, -0.12308032, -0.04206207, -0.17663766,  0.00759177,
#          0.00375117, -0.01073962,  0.06956212, -0.13910975, -0.07433864,
#         -0.19374779, -0.15901224, -0.07772785, -0.05865358,  0.02065927,
#         -0.01829238, -0.15737937,  0.02368862,  0.02465764,  0.01985077,
#         -0.07530488,  0.08171446,  0.06894507, -0.04200323,  0.09762152,
#          0.13460778,  0.02015738,  0.16825186, -0.11614238, -0.07777441,
#          0.03470143,  0.10636192, -0.09531011]], dtype=float32), array([[ 0.0987846 ,  0.08407656, -0.08965554,  0.04880472,  0.0785569 ,
#          0.02083019,  0.01059781, -0.12822412, -0.04264648,  0.03328915,
#         -0.10658157, -0.17327031, -0.04720983, -0.03468718,  0.02332898,
#         -0.02704155,  0.09815984, -0.03568261, -0.08414967, -0.15325896,
#          0.11626047,  0.02463885,  0.06241727, -0.03061579,  0.06405769,
#         -0.08562537, -0.112847  ,  0.01017978, -0.05413457,  0.17608559,
#          0.16096716, -0.00446905, -0.04185188,  0.13514067,  0.14615873,
#         -0.11079302,  0.02700577, -0.08311108,  0.11394586,  0.01017261,
#         -0.08079965,  0.04541343,  0.12329433, -0.01172021,  0.1788444 ,
#          0.07936238, -0.04525758,  0.08345538, -0.01273472,  0.04519706,
#          3.52566950e-02, -2.50295758e-01,  2.73922291e-02,
#         -8.58775452e-02,  7.29403943e-02, -1.26105875e-01,
#          5.06384447e-02,  4.01702523e-02,  1.70514118e-02,
#         -2.25855354e-02, -1.24532029e-01, -1.53359070e-01,
#          1.30126581e-01, -5.69645427e-02,  2.22623665e-02,
#         -1.11473039e-01, -9.53775719e-02, -1.30737662e-01,
#          7.15825930e-02, -1.67372212e-01, -4.62640226e-02,
#         -1.07956253e-01,  2.59642322e-02, -7.96504915e-02,
#          5.30299507e-02,  3.31821069e-02,  2.67952308e-02,
#         -3.54336351e-02,  1.36279196e-01, -3.38903069e-02,
#         -8.20648819e-02, -2.17408612e-02,  1.33468717e-01,
#         -1.07084364e-02, -4.98375334e-02,  1.70404315e-01,
#         -1.99680235e-02, -6.15978800e-03, -1.79176271e-01,
#          1.49988085e-01, -6.53381720e-02]], dtype=float32)

# %% [markdown]
# # Face Verification

# %%
#face verification
def verify(image, identity, database, model):
    """
    Function that verifies if the person on the "image_path" image is "identity".
    
    Arguments:
        image_path -- path to an image
        identity -- string, name of the person you'd like to verify the identity. Has to be an employee who works in the office.
        database -- python dictionary mapping names of allowed people's names (strings) to their encodings (vectors).
        model -- your Inception model instance in Keras
    
    Returns:
        dist -- distance between the image_path and the image of "identity" in the database.
        door_open -- True, if the door should open. False otherwise.
    """
    ### START CODE HERE
    # Step 1: Compute the encoding for the image. Use img_to_encoding() see example above. (≈ 1 line)
#     image_RGB = cv.cvtColor(image,cv.COLOR_BGR2RGB)
#     pixel = detector.detect_faces(image_RGB)
#     x,y,w,h = pixel[0]['box']
#     img = image_RGB[y:y+h,x:x+w]
    encoding = img_to_encoding(image,model)
    for i in database[identity]:
        # Step 2: Compute distance with identity's image (≈ 1 line)
        print(i)
        dist = np.linalg.norm(encoding - i)
        # Step 3: Open the door if dist < 0.7, else don't open (≈ 3 lines)
        if dist<0.6:
            print("It's " + str(identity) + ", welcome in!")
            door_open = True
            break
        else:
            print("It's not " + str(identity) + ", please go away")
            door_open = False
            break
    ### END CODE HERE        
    return dist, door_open,encoding

# %%
distance, door_open_flag, encoding = verify(cv.imread("extract_face/Abhi/IMG_20240212_234902823.jpg"), "Abhi", database, FRmodel)
print("(", distance, ",", door_open_flag, ")")
print(encoding.shape)
# Out:
# [[ 0.02068297 -0.01604011 -0.08955532  0.05583676  0.02162544 -0.0628331
#    0.02130852 -0.13848968 -0.07832345  0.13074099 -0.12317941 -0.15530987
#   -0.11236671 -0.05847793  0.07243551  0.01841416  0.09190463 -0.06605355
#    0.01156814 -0.16260362  0.13500682 -0.0922985   0.06637803  0.06649935
#    0.14304133 -0.00581338 -0.00210483  0.06589484  0.04895082  0.20700641
#    0.08103833 -0.01069203 -0.02981001  0.04828461  0.1424793  -0.02060016
#   -0.05232676 -0.00716505  0.1885734   0.01961722 -0.15096465  0.09344038
#    0.0742761   0.01870793  0.15188515  0.14620714 -0.10442546  0.02208454
#   -0.12151846  0.05096523 -0.1533642  -0.02903488 -0.0330454   0.09123479
#   -0.04741023  0.09471291  0.0912241  -0.05111816 -0.02987656 -0.02421962
#   -0.08847174 -0.0320111   0.10343746 -0.13857713 -0.15639973 -0.02654989
#   -0.11775631 -0.00770302 -0.06835135 -0.05169112  0.13090482  0.03830661
#   -0.06665146 -0.09725221 -0.02670032 -0.01476189  0.01729081 -0.01985578
#    0.02144642  0.03147482  0.12436042  0.03182223  0.00057625 -0.02919661
#    0.02150014  0.00565283 -0.04919843 -0.03300241 -0.08011401 -0.04201139
#    0.09450141  0.10199548 -0.02677247  0.16978182 -0.05082077  0.04504883
#   -0.12308032 -0.04206207 -0.17663766  0.00759177  0.00375117 -0.01073962
#    0.06956212 -0.13910975 -0.07433864 -0.19374779 -0.15901224 -0.07772785
#   -0.05865358  0.02065927 -0.01829238 -0.15737937  0.02368862  0.02465764
#    0.01985077 -0.07530488  0.08171446  0.06894507 -0.04200323  0.09762152
#    0.13460778  0.02015738  0.16825186 -0.11614238 -0.07777441  0.03470143
#    0.10636192 -0.09531011]]
# It's not Abhi, please go away
# ( 0.7536025 , False )
# (1, 128)

# %% [markdown]
# # Face Recognition

# %%
#face recognition
def who_is_it(image, database, model):
    """
    Implements face recognition for the office by finding who is the person on the image_path image.
    
    Arguments:
        image_path -- path to an image
        database -- database containing image encodings along with the name of the person on the image
        model -- your Inception model instance in Keras
    
    Returns:
        min_dist -- the minimum distance between image_path encoding and the encodings from the database
        identity -- string, the name prediction for the person on image_path
    """
    
    ### START CODE HERE
    
#     image_RGB = cv.cvtColor(image,cv.COLOR_BGR2RGB)
#     pixel = detector.detect_faces(image_RGB)
#     x,y,w,h = pixel[0]['box']
#     img = image_RGB[y:y+h,x:x+w]

    ## Step 1: Compute the target "encoding" for the image. Use img_to_encoding() see example above. ## (≈ 1 line)
    encoding =  img_to_encoding(image,model)
    
    ## Step 2: Find the closest encoding ##
    
    # Initialize "min_dist" to a large value, say 100 (≈1 line)
    min_dist = 100
    
    # Loop over the database dictionary's names and encodings.
    for (name, db_enc) in database.items():
        
        for i in db_enc:
            # Compute L2 distance between the target "encoding" and the current db_enc from the database. (≈ 1 line)
            dist = np.linalg.norm(encoding - i)

            # If this distance is less than the min_dist, then set min_dist to dist, and identity to name. (≈ 3 lines)
            if dist<min_dist:
                min_dist = dist
                identity = name
    ### END CODE HERE
    
    if min_dist > 0.55:
        print()
    else:
        print ("it's " + str(identity) + ", the distance is " + str(min_dist))
        
        
    return min_dist, identity

# %%
#image_RGB = cv.cvtColor(cv.imread("Data/val/jay/12.jpg"),cv.COLOR_BGR2RGB)
# pixel = detector.detect_faces(image_RGB)
# x,y,w,h = pixel[0]['box']
# img = image_RGB[y:y+h,x:x+w]
img = cv.imread("extract_face/Rutvik/IMG_20240209_200229541.jpg")
# color = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
# face = haar_casecade.detectMultiScale(color,
#                                           scaleFactor=1.3,
#                                          minNeighbors=5,)
# for (x,y,w,h) in face:
#     image = img[y:y+h,x:x+w]
test1 = who_is_it(img, database, FRmodel)
# Out:
# it's Rutvik, the distance is 0.0

# %% [markdown]
# #  Face Detection

# %%
haar_casecade = cv.CascadeClassifier("utils/haar_face.xml")

# %%
# !pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in c:\users\admin\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from mtcnn) (2.12.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\admin\anaconda3\lib\site-packages (from mtcnn) (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn) (1.23.5)

# %%
from mtcnn import MTCNN

# %%
detector = MTCNN()

# %%
import face_recognition
import dlib

# %% [markdown]
# # Face Detection and Recognition

# %%
cap = cv.VideoCapture(0)
# fourcc = cv.VideoWriter_fourcc(*'XVID')
# out = cv.VideoWriter("output.mp4",fourcc,10.00,(640,480))

while True:
    content,frame = cap.read()
    gray = cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
#     image_RGB = cv.cvtColor(frame,cv.COLOR_BGR2RGB)
    faces = haar_casecade.detectMultiScale(gray,
                                          scaleFactor=1.3,
                                          minNeighbors=4,
                                        )
    
#     face = detector.detect_faces(image_RGB)
#     if face != []:
#         box = np.array([face[0]['box']])
    
#     face_detector = dlib.get_frontal_face_detector()
#     landmark_predictor = dlib.shape_predictor("utils/shape_predictor_68_face_landmarks.dat")
    
    #faces = face_detector(gray)

    for (x,y,w,h) in faces:
        
        #x, y, w, h = face.left(), face.top(), face.width(), face.height()
        cv.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),thickness=2)
        # Extract the face region
        face1 = frame[y:y+h, x:x+w]
        
        
        # Perform face alignment using facial landmarks
        face_locations = face_recognition.face_locations(frame)
        face_landmarks = face_recognition.face_landmarks(frame, face_locations)
        #print(face_landmarks)

#         for landmarks in face_landmarks:
#             # Get coordinates of left eye, right eye, and nose tip
#             left_eye = landmarks['left_eye']
#             right_eye = landmarks['right_eye']
#             nose_tip = landmarks['nose_tip']

#             # Calculate the center of mass for the eyes
#             left_eye_center = np.mean(left_eye, axis=0).astype(int)
#             right_eye_center = np.mean(right_eye, axis=0).astype(int)

#             # Calculate the angle between the eyes
#             angle = np.degrees(np.arctan2(right_eye_center[1] - left_eye_center[1], right_eye_center[0] - left_eye_center[0]))

#             # Perform rotation to align the face
#             rotation_matrix = cv.getRotationMatrix2D(tuple(nose_tip[0]), angle, scale=1)
#             aligned_face = cv.warpAffine(face, rotation_matrix, (w, h), flags=cv.INTER_LINEAR)

            
        mindist,identity = who_is_it(face1,database,FRmodel)

        if mindist<0.6:
            cv.putText(frame,identity,(x,y-10),cv.FONT_HERSHEY_PLAIN,2,(0,255,0),2,cv.LINE_AA)           
#         else:
#             cv.putText(frame,'Unknown',(x,y-10),cv.FONT_HERSHEY_PLAIN,2,(0,0,255),2,cv.LINE_AA)
            
    #out.write(frame)


    cv.imshow("video",frame)
    
    if cv.waitKey(2) & 0xFF == ord('x'):
        break

cap.release()
#out.release()
cv.destroyAllWindows()

# %% [markdown]
# # Face Detection Using Mediapipe

# %%
import time
import cv2 as cv
import mediapipe as mp
import numpy as np

mp_face_detection = mp.solutions.face_detection
cap = cv.VideoCapture(0)
with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detector:
    frame_counter = 0
    fonts = cv.FONT_HERSHEY_PLAIN
    start_time = time.time()
    while True:
        frame_counter += 1
        ret, frame = cap.read()
        if ret is False:
            break
        rgb_frame = cv.cvtColor(frame, cv.COLOR_BGR2RGB)

        results = face_detector.process(rgb_frame)
        frame_height, frame_width, c = frame.shape
        if results.detections:
            for face in results.detections:
                face_react = np.multiply(
                    [
                        face.location_data.relative_bounding_box.xmin,
                        face.location_data.relative_bounding_box.ymin,
                        face.location_data.relative_bounding_box.width,
                        face.location_data.relative_bounding_box.height,
                    ],
                    [frame_width, frame_height, frame_width, frame_height]).astype(int)
                #print(face_react)
                x = face_react[0]
                y = face_react[1]
                w = face_react[2]
                h = face_react[3]
                face = frame[y:y+h,x:x+w]
                
                cv.rectangle(frame, face_react, color=(255, 255, 255), thickness=2)
#                 key_points = np.array([(p.x, p.y) for p in face.location_data.relative_keypoints])
#                 key_points_coords = np.multiply(key_points,[frame_width,frame_height]).astype(int)
#                 for p in key_points_coords:
#                     cv.circle(frame, p, 4, (255, 255, 255), 2)
#                     cv.circle(frame, p, 2, (0, 0, 0), -1)
                mindist,identity = who_is_it(face,database,FRmodel)

                if mindist<0.55:
                    cv.putText(frame,identity,(x,y-10),cv.FONT_HERSHEY_PLAIN,2,(0,255,0),2,cv.LINE_AA)           
#                 else:
#                     cv.putText(frame,'Unknown',(x,y-10),cv.FONT_HERSHEY_PLAIN,2,(0,0,255),2,cv.LINE_AA)
        
        fps = frame_counter / (time.time() - start_time)
        cv.putText(frame,f"FPS: {fps:.2f}",(30, 30),cv.FONT_HERSHEY_DUPLEX,0.7,(0, 255, 255),2,)
        cv.imshow("frame", frame)
        
        if cv.waitKey(1) & 0xFF == ord("x"):
            break
    cap.release()
    cv.destroyAllWindows()
# Out:
# it's Jay, the distance is 0.46010956
#
# it's Jay, the distance is 0.45048702
# it's Jay, the distance is 0.44716856
# it's Jay, the distance is 0.4992445
# it's Jay, the distance is 0.50199705
# it's Jay, the distance is 0.40094328
#
# it's Jay, the distance is 0.48188803
# it's Jay, the distance is 0.48903847
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# it's Jay, the distance is 0.54906905
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# it's Jay, the distance is 0.5014442
#
#
#
#
#
#
# it's Jay, the distance is 0.44503146
# it's Jay, the distance is 0.44503146
#
#
#
#
#
# it's Jay, the distance is 0.37204057
# it's Jay, the distance is 0.53096694
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# it's Jay, the distance is 0.4734183
# it's Jay, the distance is 0.45348564
# it's Jay, the distance is 0.4347718
# it's Jay, the distance is 0.3714331
# it's Jay, the distance is 0.45441815
# it's Jay, the distance is 0.40599543
# it's Jay, the distance is 0.37093756
# it's Jay, the distance is 0.41559097
# it's Jay, the distance is 0.44220448
# it's Jay, the distance is 0.4228995
# it's Jay, the distance is 0.34137404
#
#
#
#
#
#
# it's Jay, the distance is 0.36490375
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# it's Prince, the distance is 0.5166782
# it's Prince, the distance is 0.4989783
# it's Prince, the distance is 0.50836384
# it's Prince, the distance is 0.4704856
# it's Prince, the distance is 0.4868606
# it's Prince, the distance is 0.4631247
# it's Prince, the distance is 0.44381323
# it's Prince, the distance is 0.50639284
# it's Prince, the distance is 0.48995033
# it's Prince, the distance is 0.35144687
# it's Prince, the distance is 0.41272292
# it's Prince, the distance is 0.41592437
# it's Prince, the distance is 0.37046364
# it's Prince, the distance is 0.33254725
# it's Prince, the distance is 0.38454694
# it's Prince, the distance is 0.42717972
# it's Prince, the distance is 0.5311825
#
# it's Prince, the distance is 0.46779573
# it's Prince, the distance is 0.3796217
# it's Prince, the distance is 0.41009834
# it's Prince, the distance is 0.36995402
# it's Prince, the distance is 0.34769154
# it's Prince, the distance is 0.41187215
# it's Prince, the distance is 0.33422485
# it's Prince, the distance is 0.36298552
# it's Prince, the distance is 0.42251387
# it's Prince, the distance is 0.3909258
# it's Prince, the distance is 0.40319934
# it's Prince, the distance is 0.41326734
# it's Prince, the distance is 0.37806627
# it's Prince, the distance is 0.35148764
# it's Prince, the distance is 0.45490673
# it's Prince, the distance is 0.39940557
# it's Prince, the distance is 0.41340908
# it's Prince, the distance is 0.45347655
# it's Prince, the distance is 0.38863927
# it's Prince, the distance is 0.48772955
# it's Prince, the distance is 0.44812658
# it's Prince, the distance is 0.48406085
# it's Prince, the distance is 0.48734254
# it's Prince, the distance is 0.4531247
# it's Prince, the distance is 0.46266162
# it's Prince, the distance is 0.47997567
# it's Prince, the distance is 0.47241813
# it's Prince, the distance is 0.4767034
# it's Prince, the distance is 0.4204206
# it's Prince, the distance is 0.4605537
# it's Prince, the distance is 0.4283207
# it's Prince, the distance is 0.39411387
# it's Prince, the distance is 0.46308798
# it's Jay, the distance is 0.5005637
# it's Jay, the distance is 0.48801732
# it's Jay, the distance is 0.4895621
# it's Jay, the distance is 0.5052832
# it's Jay, the distance is 0.5225345
# it's Jay, the distance is 0.4774239
# it's Jay, the distance is 0.5372577
# it's Jay, the distance is 0.53603935
# it's Jay, the distance is 0.5142713
# it's Jay, the distance is 0.5345265
# it's Jay, the distance is 0.47211617
# it's Jay, the distance is 0.508409
#
# it's Jay, the distance is 0.45963115
# it's Jay, the distance is 0.43496838
# it's Jay, the distance is 0.4092929
# it's Jay, the distance is 0.38439804
# it's Jay, the distance is 0.38439804
# it's Jay, the distance is 0.39278692
#
#
#
#
#
#
#
#
# it's Jay, the distance is 0.5087791
# it's Jay, the distance is 0.43409136
# it's Jay, the distance is 0.38541052
# it's Jay, the distance is 0.3895393
# it's Jay, the distance is 0.40249985
# it's Jay, the distance is 0.4811185
# it's Jay, the distance is 0.37308457
# it's Jay, the distance is 0.39177233
# it's Jay, the distance is 0.42846003
# it's Jay, the distance is 0.3952606
# it's Jay, the distance is 0.45605925
# it's Jay, the distance is 0.38947588
# it's Jay, the distance is 0.36823815

# %%
#save model

FRmodel.save("saved_model.h5")

# %%
#convert into tflite

import tensorflow as tf
from tensorflow.keras.models import load_model

# Load the Keras model
loaded_model = load_model('saved_model.h5')

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
tflite_model = converter.convert()

# Save the TFLite model
with open('saved_model.tflite', 'wb') as f:
    f.write(tflite_model)
